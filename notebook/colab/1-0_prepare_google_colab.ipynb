# %% [markdown]
# # はじめに
#
# 本ファイルは、リファレンス環境（ソフトウェア）をGoogle Colaboratoryで実行するための環境構築の手順を示したものです。
#
# 本ファイルの作業は、初回実行時に1度だけ行います。2回目以降は、本作業は不要です。

# %% [markdown]
# # リファレンス環境（ソフトウェア）のGitHubリポジトリをクローン

# %% [markdown]
# - Googleドライブをマウントします。

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - 予め、Googleドライブ上に作業ディレクトリを作成しておきます。
#   本ファイルでは、作業ディレクトリを `work` としています。
#
# - 作業ディレクトリに移動し、GitHubからリファレンス環境（ソフトウェア）のリポジトリをcloneします。

# %%
# WORK_DIRのパスは自身の作業ディレクトリに変更してください。

WORK_DIR = "/content/drive/MyDrive/Colab Notebooks/work/"
# %cd $WORK_DIR
# Out:
# /content/drive/MyDrive/Colab Notebooks/work

# %%
# !git clone https://github.com/pometa0507/6th-ai-reference2.git
# Out:
# Cloning into '6th-ai-reference2'...
# remote: Enumerating objects: 247, done.
# remote: Counting objects: 100% (247/247), done.
# remote: Compressing objects: 100% (200/200), done.
# remote: Total 247 (delta 38), reused 247 (delta 38), pack-reused 0
# Receiving objects: 100% (247/247), 9.23 MiB | 9.40 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Checking out files: 100% (211/211), done.

# %% [markdown]
# # データセットの用意
#
# [#データセットの用意](https://github.com/pometa0507/6th-ai-reference2#%E3%83%87%E3%83%BC%E3%82%BF%E3%82%BB%E3%83%83%E3%83%88%E3%81%AE%E7%94%A8%E6%84%8F)を参考に、Googleドライブ上に下記のディレクトリ構成となるようにデータセットを用意します。
#
# ```
# {WORK_DIR}/6th-ai-reference2
# └ data
#     ├ 3d_labels
#         ├ maps
#         ├ samples
#             ├ CAM_FRONT
#             └ LIDAR_TOP
#         └ v1.0-trainval
#             :
#             ├ sample_annotation.json  <- 修正版に置き換えます
#             :
# ```

# %% [markdown]
# # 学習済みモデル
#
# [#学習済みモデル](https://github.com/pometa0507/6th-ai-reference2#%E5%AD%A6%E7%BF%92%E6%B8%88%E3%81%BF%E3%83%A2%E3%83%87%E3%83%AB)を参考に、Googleドライブ上に下記のディレクトリ構成となるように学習済みモデルを用意します。
#
# ```
# {WORK_DIR}/6th-ai-reference2
# └ second.pytorch
#      └─ checkpoints
#           └ pointpainting
#                 ├── summary
#                 ├── checkpoints.json
#                 └── voxelnet-24000.tckpt
# ```
#
# 以上
